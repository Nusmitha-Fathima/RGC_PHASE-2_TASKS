# %% [markdown]
# ### Missing Value Treatment

# %%
import pandas as pd
import numpy as np

# %%
data = { 'Age': [25, 30, np.nan, 35, 40, np.nan, 22, 28, 45, 50, np.nan, 37, 29, 41, 48, 33, 38, np.nan, 44, 51], 
        'Income': [50000, 60000, 75000, np.nan, 80000, 42000, 55000, np.nan, 67000, 72000, np.nan, 69000, 59000, 68000, 62000, 71000, 58000, np.nan, 70000, np.nan],
        'Gender': ['M', 'F', np.nan, 'F', 'M', np.nan, 'M', 'F', 'M', 'M', np.nan, 'M', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'M'], 
        'Education': ['Bachelor', 'Master', np.nan, 'Bachelor', 'Bachelor', 'Master', 'PhD', np.nan, 'Bachelor', 'PhD', 'Bachelor', 'Master', 'PhD', 'Bachelor', 'Master', 'Bachelor', 'Master', 'PhD', 'Bachelor', np.nan], 
        'Employment_Status': ['Employed', 'Employed', 'Unemployed', 'Employed', 'Employed', 'Employed', np.nan, 'Employed', 'Employed', 'Employed', 'Employed', 'Unemployed', 'Employed', 'Employed', 'Employed', 'Employed', 'Unemployed', 'Employed', 'Employed', 'Employed'],
        'Years_of_Experience': [3, 5, 0, 8, 10, 2, 0, 4, 12, 15, np.nan, 9, 4, 11, 14, 7, 13, 1, 5, 16],
        'Marital_Status': ['Single', 'Married', 'Single', 'Married', 'Single', 'Married', np.nan, 'Married', 'Single', 'Married', 'Single', 'Married', 'Single', 'Married', 'Single', 'Married', 'Single', np.nan, 'Married', 'Married'],
        'Children_Count': [0, 1, 0, 2, 0, 2, np.nan, 3, 1, 2, 2, 1, 0, 3, 2, 1, 2, 0, 2, np.nan],
        'Home_Ownership': ['Rent', 'Own', 'Rent', 'Own', 'Rent', 'Own', np.nan, 'Own', 'Rent', 'Own', 'Rent', 'Own', 'Rent', 'Own', 'Rent', 'Own', 'Rent', 'Rent', 'Own', np.nan] }

# %%
df=pd.DataFrame(data)
df
# Out:
#      Age   Income Gender Education Employment_Status  Years_of_Experience  \
# 0   25.0  50000.0      M  Bachelor          Employed                  3.0
# 1   30.0  60000.0      F    Master          Employed                  5.0
# 2    NaN  75000.0    NaN       NaN        Unemployed                  0.0
# 3   35.0      NaN      F  Bachelor          Employed                  8.0
# 4   40.0  80000.0      M  Bachelor          Employed                 10.0
# 5    NaN  42000.0    NaN    Master          Employed                  2.0
# 6   22.0  55000.0      M       PhD               NaN                  0.0
# 7   28.0      NaN      F       NaN          Employed                  4.0
# 8   45.0  67000.0      M  Bachelor          Employed                 12.0
# 9   50.0  72000.0      M       PhD          Employed                 15.0
# 10   NaN      NaN    NaN  Bachelor          Employed                  NaN
# 11  37.0  69000.0      M    Master        Unemployed                  9.0
# 12  29.0  59000.0      F       PhD          Employed                  4.0
# 13  41.0  68000.0      M  Bachelor          Employed                 11.0
# 14  48.0  62000.0      F    Master          Employed                 14.0
# 15  33.0  71000.0      F  Bachelor          Employed                  7.0
# 16  38.0  58000.0      M    Master        Unemployed                 13.0
# 17   NaN      NaN      M       PhD          Employed                  1.0
# 18  44.0  70000.0      F  Bachelor          Employed                  5.0
# 19  51.0      NaN      M       NaN          Employed                 16.0
#
#    Marital_Status  Children_Count Home_Ownership
# 0          Single             0.0           Rent
# 1         Married             1.0            Own
# 2          Single             0.0           Rent
# 3         Married             2.0            Own
# 4          Single             0.0           Rent
# 5         Married             2.0            Own
# 6             NaN             NaN            NaN
# 7         Married             3.0            Own
# 8          Single             1.0           Rent
# 9         Married             2.0            Own
# 10         Single             2.0           Rent
# 11        Married             1.0            Own
# 12         Single             0.0           Rent
# 13        Married             3.0            Own
# 14         Single             2.0           Rent
# 15        Married             1.0            Own
# 16         Single             2.0           Rent
# 17            NaN             0.0           Rent
# 18        Married             2.0            Own
# 19        Married             NaN            NaN

# %% [markdown]
# ### What percentage of missing values is there in the 'Income' column?

# %%
specified_column = 'Income'
missing_percentage = (df[specified_column].isnull().sum() / len(df)) * 100
print(f"Percentage of missing values in column '{specified_column}': {missing_percentage:.2f}%")
# Out:
# Percentage of missing values in column 'Income': 25.00%

# %% [markdown]
# ### What is the most common education level ('Education' column) among the non-missing values?

# %%
mode_value = df['Education'].mode().iloc[0]      #iloc[0] is used to select the first (most common) mode value from the Series
mode_value
# Out:
# 'Bachelor'

# %% [markdown]
# ### How many individuals are employed ('Employment_Status' column) among the non-missing values?

# %%
column = 'Employment_Status'
value = 'Employed'
count = df[df[column].notnull()][column].eq(value).sum()
count
# Out:
# 16

# %% [markdown]
# ### What is the average 'Years_of_Experience' among individuals with non-missing values for this column?

# %%
average = df['Years_of_Experience'].mean()
average
# Out:
# 7.315789473684211

# %% [markdown]
# ### How many individuals have 'Marital_Status' set to 'Married' among the non-missing values?

# %%
column = 'Marital_Status'
value = 'Married'
count = df[df[column].notnull()][column].eq(value).sum()
count
# Out:
# 10

# %% [markdown]
# ### What is the most common home ownership status ('Home_Ownership' column) among the non-missing values?

# %%
common_status = df['Home_Ownership'].mode().iloc[0]
common_status
# Out:
# 'Own'

# %% [markdown]
# ### change the value of employee status to unemployed if the education is bachelor

# %%
df.loc[df['Education'] == 'Bachelor', 'Employment_Status'] = 'Unemployed'
df
# Out:
#      Age   Income Gender Education Employment_Status  Years_of_Experience  \
# 0   25.0  50000.0      M  Bachelor        Unemployed                  3.0
# 1   30.0  60000.0      F    Master          Employed                  5.0
# 2    NaN  75000.0    NaN       NaN        Unemployed                  0.0
# 3   35.0      NaN      F  Bachelor        Unemployed                  8.0
# 4   40.0  80000.0      M  Bachelor        Unemployed                 10.0
# 5    NaN  42000.0    NaN    Master          Employed                  2.0
# 6   22.0  55000.0      M       PhD               NaN                  0.0
# 7   28.0      NaN      F       NaN          Employed                  4.0
# 8   45.0  67000.0      M  Bachelor        Unemployed                 12.0
# 9   50.0  72000.0      M       PhD          Employed                 15.0
# 10   NaN      NaN    NaN  Bachelor        Unemployed                  NaN
# 11  37.0  69000.0      M    Master        Unemployed                  9.0
# 12  29.0  59000.0      F       PhD          Employed                  4.0
# 13  41.0  68000.0      M  Bachelor        Unemployed                 11.0
# 14  48.0  62000.0      F    Master          Employed                 14.0
# 15  33.0  71000.0      F  Bachelor        Unemployed                  7.0
# 16  38.0  58000.0      M    Master        Unemployed                 13.0
# 17   NaN      NaN      M       PhD          Employed                  1.0
# 18  44.0  70000.0      F  Bachelor        Unemployed                  5.0
# 19  51.0      NaN      M       NaN          Employed                 16.0
#
#    Marital_Status  Children_Count Home_Ownership
# 0          Single             0.0           Rent
# 1         Married             1.0            Own
# 2          Single             0.0           Rent
# 3         Married             2.0            Own
# 4          Single             0.0           Rent
# 5         Married             2.0            Own
# 6             NaN             NaN            NaN
# 7         Married             3.0            Own
# 8          Single             1.0           Rent
# 9         Married             2.0            Own
# 10         Single             2.0           Rent
# 11        Married             1.0            Own
# 12         Single             0.0           Rent
# 13        Married             3.0            Own
# 14         Single             2.0           Rent
# 15        Married             1.0            Own
# 16         Single             2.0           Rent
# 17            NaN             0.0           Rent
# 18        Married             2.0            Own
# 19        Married             NaN            NaN

# %% [markdown]
# ### find the average sallary of each educational group

# %%
average_salary = df.groupby('Education')['Income'].mean()
average_salary
# Out:
# Education
# Bachelor    67666.666667
# Master      58200.000000
# PhD         62000.000000
# Name: Income, dtype: float64

# %% [markdown]
# ### Random Sample Imputation

# %%
non_missing_values = df['Education'].dropna()
non_missing_values
# Out:
# 0     Bachelor
# 1       Master
# 3     Bachelor
# 4     Bachelor
# 5       Master
# 6          PhD
# 8     Bachelor
# 9          PhD
# 10    Bachelor
# 11      Master
# 12         PhD
# 13    Bachelor
# 14      Master
# 15    Bachelor
# 16      Master
# 17         PhD
# 18    Bachelor
# Name: Education, dtype: object

# %%
num_missing_values = df['Education'].isnull().sum()
num_missing_values
# Out:
# 3

# %%
random_indices = np.random.choice(non_missing_values.index, size=num_missing_values, replace=True)
random_indices
# Out:
# array([16, 13, 12], dtype=int64)

# %%
df.loc[df['Education'].isnull(), 'Education'] = non_missing_values.loc[random_indices].values
df.loc[df['Education'].isnull(), 'Education']
# Out:
# Series([], Name: Education, dtype: object)

# %%
df
# Out:
#      Age   Income Gender Education Employment_Status  Years_of_Experience  \
# 0   25.0  50000.0      M  Bachelor        Unemployed                  3.0
# 1   30.0  60000.0      F    Master          Employed                  5.0
# 2    NaN  75000.0    NaN    Master        Unemployed                  0.0
# 3   35.0      NaN      F  Bachelor        Unemployed                  8.0
# 4   40.0  80000.0      M  Bachelor        Unemployed                 10.0
# 5    NaN  42000.0    NaN    Master          Employed                  2.0
# 6   22.0  55000.0      M       PhD               NaN                  0.0
# 7   28.0      NaN      F  Bachelor          Employed                  4.0
# 8   45.0  67000.0      M  Bachelor        Unemployed                 12.0
# 9   50.0  72000.0      M       PhD          Employed                 15.0
# 10   NaN      NaN    NaN  Bachelor        Unemployed                  NaN
# 11  37.0  69000.0      M    Master        Unemployed                  9.0
# 12  29.0  59000.0      F       PhD          Employed                  4.0
# 13  41.0  68000.0      M  Bachelor        Unemployed                 11.0
# 14  48.0  62000.0      F    Master          Employed                 14.0
# 15  33.0  71000.0      F  Bachelor        Unemployed                  7.0
# 16  38.0  58000.0      M    Master        Unemployed                 13.0
# 17   NaN      NaN      M       PhD          Employed                  1.0
# 18  44.0  70000.0      F  Bachelor        Unemployed                  5.0
# 19  51.0      NaN      M       PhD          Employed                 16.0
#
#    Marital_Status  Children_Count Home_Ownership
# 0          Single             0.0           Rent
# 1         Married             1.0            Own
# 2          Single             0.0           Rent
# 3         Married             2.0            Own
# 4          Single             0.0           Rent
# 5         Married             2.0            Own
# 6             NaN             NaN            NaN
# 7         Married             3.0            Own
# 8          Single             1.0           Rent
# 9         Married             2.0            Own
# 10         Single             2.0           Rent
# 11        Married             1.0            Own
# 12         Single             0.0           Rent
# 13        Married             3.0            Own
# 14         Single             2.0           Rent
# 15        Married             1.0            Own
# 16         Single             2.0           Rent
# 17            NaN             0.0           Rent
# 18        Married             2.0            Own
# 19        Married             NaN            NaN

# %% [markdown]
# ### Capturing NAN values with a new feature

# %%
df['Age_Missing'] = df['Age'].isnull().astype(int)
df['Income_Missing'] = df['Income'].isnull().astype(int)
df['Gender_Missing'] = df['Gender'].isnull().astype(int)

# %%
df
# Out:
#      Age   Income Gender Education Employment_Status  Years_of_Experience  \
# 0   25.0  50000.0      M  Bachelor        Unemployed                  3.0
# 1   30.0  60000.0      F    Master          Employed                  5.0
# 2    NaN  75000.0    NaN    Master        Unemployed                  0.0
# 3   35.0      NaN      F  Bachelor        Unemployed                  8.0
# 4   40.0  80000.0      M  Bachelor        Unemployed                 10.0
# 5    NaN  42000.0    NaN    Master          Employed                  2.0
# 6   22.0  55000.0      M       PhD               NaN                  0.0
# 7   28.0      NaN      F  Bachelor          Employed                  4.0
# 8   45.0  67000.0      M  Bachelor        Unemployed                 12.0
# 9   50.0  72000.0      M       PhD          Employed                 15.0
# 10   NaN      NaN    NaN  Bachelor        Unemployed                  NaN
# 11  37.0  69000.0      M    Master        Unemployed                  9.0
# 12  29.0  59000.0      F       PhD          Employed                  4.0
# 13  41.0  68000.0      M  Bachelor        Unemployed                 11.0
# 14  48.0  62000.0      F    Master          Employed                 14.0
# 15  33.0  71000.0      F  Bachelor        Unemployed                  7.0
# 16  38.0  58000.0      M    Master        Unemployed                 13.0
# 17   NaN      NaN      M       PhD          Employed                  1.0
# 18  44.0  70000.0      F  Bachelor        Unemployed                  5.0
# 19  51.0      NaN      M       PhD          Employed                 16.0
#
#    Marital_Status  Children_Count Home_Ownership  Age_Missing  Income_Missing  \
# 0          Single             0.0           Rent            0               0
# 1         Married             1.0            Own            0               0
# 2          Single             0.0           Rent            1               0
# 3         Married             2.0            Own            0               1
# 4          Single             0.0           Rent            0               0
# 5         Married             2.0            Own            1               0
# 6             NaN             NaN            NaN            0               0
# 7         Married             3.0            Own            0               1
# 8          Single             1.0           Rent            0               0
# 9         Married             2.0            Own            0               0
# 10         Single             2.0           Rent            1               1
# 11        Married             1.0            Own            0               0
# 12         Single             0.0           Rent            0               0
# 13        Married             3.0            Own            0               0
# 14         Single             2.0           Rent            0               0
# 15        Married             1.0            Own            0               0
# 16         Single             2.0           Rent            0               0
# 17            NaN             0.0           Rent            1               1
# 18        Married             2.0            Own            0               0
# 19        Married             NaN            NaN            0               1
#
#     Gender_Missing
# 0                0
# 1                0
# 2                1
# 3                0
# 4                0
# 5                1
# 6                0
# 7                0
# 8                0
# 9                0
# 10               1
# 11               0
# 12               0
# 13               0
# 14               0
# 15               0
# 16               0
# 17               0
# 18               0
# 19               0

# %% [markdown]
# ### Arbitrary imputation

# %%
arbitrary_value = -1
df['Age'].fillna(arbitrary_value)
# Out:
# 0     25.0
# 1     30.0
# 2     -1.0
# 3     35.0
# 4     40.0
# 5     -1.0
# 6     22.0
# 7     28.0
# 8     45.0
# 9     50.0
# 10    -1.0
# 11    37.0
# 12    29.0
# 13    41.0
# 14    48.0
# 15    33.0
# 16    38.0
# 17    -1.0
# 18    44.0
# 19    51.0
# Name: Age, dtype: float64

# %% [markdown]
# ### End of Distribution imputation

# %%
df['Age'].fillna(df['Age'].max(), inplace=True)
df
# Out:
#      Age   Income Gender Education Employment_Status  Years_of_Experience  \
# 0   25.0  50000.0      M  Bachelor        Unemployed                  3.0
# 1   30.0  60000.0      F    Master          Employed                  5.0
# 2   51.0  75000.0    NaN    Master        Unemployed                  0.0
# 3   35.0      NaN      F  Bachelor        Unemployed                  8.0
# 4   40.0  80000.0      M  Bachelor        Unemployed                 10.0
# 5   51.0  42000.0    NaN    Master          Employed                  2.0
# 6   22.0  55000.0      M       PhD               NaN                  0.0
# 7   28.0      NaN      F  Bachelor          Employed                  4.0
# 8   45.0  67000.0      M  Bachelor        Unemployed                 12.0
# 9   50.0  72000.0      M       PhD          Employed                 15.0
# 10  51.0      NaN    NaN  Bachelor        Unemployed                  NaN
# 11  37.0  69000.0      M    Master        Unemployed                  9.0
# 12  29.0  59000.0      F       PhD          Employed                  4.0
# 13  41.0  68000.0      M  Bachelor        Unemployed                 11.0
# 14  48.0  62000.0      F    Master          Employed                 14.0
# 15  33.0  71000.0      F  Bachelor        Unemployed                  7.0
# 16  38.0  58000.0      M    Master        Unemployed                 13.0
# 17  51.0      NaN      M       PhD          Employed                  1.0
# 18  44.0  70000.0      F  Bachelor        Unemployed                  5.0
# 19  51.0      NaN      M       PhD          Employed                 16.0
#
#    Marital_Status  Children_Count Home_Ownership  Age_Missing  Income_Missing  \
# 0          Single             0.0           Rent            0               0
# 1         Married             1.0            Own            0               0
# 2          Single             0.0           Rent            1               0
# 3         Married             2.0            Own            0               1
# 4          Single             0.0           Rent            0               0
# 5         Married             2.0            Own            1               0
# 6             NaN             NaN            NaN            0               0
# 7         Married             3.0            Own            0               1
# 8          Single             1.0           Rent            0               0
# 9         Married             2.0            Own            0               0
# 10         Single             2.0           Rent            1               1
# 11        Married             1.0            Own            0               0
# 12         Single             0.0           Rent            0               0
# 13        Married             3.0            Own            0               0
# 14         Single             2.0           Rent            0               0
# 15        Married             1.0            Own            0               0
# 16         Single             2.0           Rent            0               0
# 17            NaN             0.0           Rent            1               1
# 18        Married             2.0            Own            0               0
# 19        Married             NaN            NaN            0               1
#
#     Gender_Missing
# 0                0
# 1                0
# 2                1
# 3                0
# 4                0
# 5                1
# 6                0
# 7                0
# 8                0
# 9                0
# 10               1
# 11               0
# 12               0
# 13               0
# 14               0
# 15               0
# 16               0
# 17               0
# 18               0
# 19               0

# %%
x = df["Age"].mean()

df["Age"].fillna(x,inplace=True)
df
# Out:
#      Age   Income Gender Education Employment_Status  Years_of_Experience  \
# 0   25.0  50000.0      M  Bachelor        Unemployed                  3.0
# 1   30.0  60000.0      F    Master          Employed                  5.0
# 2   51.0  75000.0    NaN    Master        Unemployed                  0.0
# 3   35.0      NaN      F  Bachelor        Unemployed                  8.0
# 4   40.0  80000.0      M  Bachelor        Unemployed                 10.0
# 5   51.0  42000.0    NaN    Master          Employed                  2.0
# 6   22.0  55000.0      M       PhD               NaN                  0.0
# 7   28.0      NaN      F  Bachelor          Employed                  4.0
# 8   45.0  67000.0      M  Bachelor        Unemployed                 12.0
# 9   50.0  72000.0      M       PhD          Employed                 15.0
# 10  51.0      NaN    NaN  Bachelor        Unemployed                  NaN
# 11  37.0  69000.0      M    Master        Unemployed                  9.0
# 12  29.0  59000.0      F       PhD          Employed                  4.0
# 13  41.0  68000.0      M  Bachelor        Unemployed                 11.0
# 14  48.0  62000.0      F    Master          Employed                 14.0
# 15  33.0  71000.0      F  Bachelor        Unemployed                  7.0
# 16  38.0  58000.0      M    Master        Unemployed                 13.0
# 17  51.0      NaN      M       PhD          Employed                  1.0
# 18  44.0  70000.0      F  Bachelor        Unemployed                  5.0
# 19  51.0      NaN      M       PhD          Employed                 16.0
#
#    Marital_Status  Children_Count Home_Ownership  Age_Missing  Income_Missing  \
# 0          Single             0.0           Rent            0               0
# 1         Married             1.0            Own            0               0
# 2          Single             0.0           Rent            1               0
# 3         Married             2.0            Own            0               1
# 4          Single             0.0           Rent            0               0
# 5         Married             2.0            Own            1               0
# 6             NaN             NaN            NaN            0               0
# 7         Married             3.0            Own            0               1
# 8          Single             1.0           Rent            0               0
# 9         Married             2.0            Own            0               0
# 10         Single             2.0           Rent            1               1
# 11        Married             1.0            Own            0               0
# 12         Single             0.0           Rent            0               0
# 13        Married             3.0            Own            0               0
# 14         Single             2.0           Rent            0               0
# 15        Married             1.0            Own            0               0
# 16         Single             2.0           Rent            0               0
# 17            NaN             0.0           Rent            1               1
# 18        Married             2.0            Own            0               0
# 19        Married             NaN            NaN            0               1
#
#     Gender_Missing
# 0                0
# 1                0
# 2                1
# 3                0
# 4                0
# 5                1
# 6                0
# 7                0
# 8                0
# 9                0
# 10               1
# 11               0
# 12               0
# 13               0
# 14               0
# 15               0
# 16               0
# 17               0
# 18               0
# 19               0

# %%
x = df["Income"].mean()
df["Income"].fillna(x,inplace=True)
df
# Out:
#      Age        Income Gender Education Employment_Status  \
# 0   25.0  50000.000000      M  Bachelor        Unemployed
# 1   30.0  60000.000000      F    Master          Employed
# 2   51.0  75000.000000    NaN    Master        Unemployed
# 3   35.0  63866.666667      F  Bachelor        Unemployed
# 4   40.0  80000.000000      M  Bachelor        Unemployed
# 5   51.0  42000.000000    NaN    Master          Employed
# 6   22.0  55000.000000      M       PhD               NaN
# 7   28.0  63866.666667      F  Bachelor          Employed
# 8   45.0  67000.000000      M  Bachelor        Unemployed
# 9   50.0  72000.000000      M       PhD          Employed
# 10  51.0  63866.666667    NaN  Bachelor        Unemployed
# 11  37.0  69000.000000      M    Master        Unemployed
# 12  29.0  59000.000000      F       PhD          Employed
# 13  41.0  68000.000000      M  Bachelor        Unemployed
# 14  48.0  62000.000000      F    Master          Employed
# 15  33.0  71000.000000      F  Bachelor        Unemployed
# 16  38.0  58000.000000      M    Master        Unemployed
# 17  51.0  63866.666667      M       PhD          Employed
# 18  44.0  70000.000000      F  Bachelor        Unemployed
# 19  51.0  63866.666667      M       PhD          Employed
#
#     Years_of_Experience Marital_Status  Children_Count Home_Ownership  \
# 0                   3.0         Single             0.0           Rent
# 1                   5.0        Married             1.0            Own
# 2                   0.0         Single             0.0           Rent
# 3                   8.0        Married             2.0            Own
# 4                  10.0         Single             0.0           Rent
# 5                   2.0        Married             2.0            Own
# 6                   0.0            NaN             NaN            NaN
# 7                   4.0        Married             3.0            Own
# 8                  12.0         Single             1.0           Rent
# 9                  15.0        Married             2.0            Own
# 10                  NaN         Single             2.0           Rent
# 11                  9.0        Married             1.0            Own
# 12                  4.0         Single             0.0           Rent
# 13                 11.0        Married             3.0            Own
# 14                 14.0         Single             2.0           Rent
# 15                  7.0        Married             1.0            Own
# 16                 13.0         Single             2.0           Rent
# 17                  1.0            NaN             0.0           Rent
# 18                  5.0        Married             2.0            Own
# 19                 16.0        Married             NaN            NaN
#
#     Age_Missing  Income_Missing  Gender_Missing
# 0             0               0               0
# 1             0               0               0
# 2             1               0               1
# 3             0               1               0
# 4             0               0               0
# 5             1               0               1
# 6             0               0               0
# 7             0               1               0
# 8             0               0               0
# 9             0               0               0
# 10            1               1               1
# 11            0               0               0
# 12            0               0               0
# 13            0               0               0
# 14            0               0               0
# 15            0               0               0
# 16            0               0               0
# 17            1               1               0
# 18            0               0               0
# 19            0               1               0

# %%
x = df["Gender"].mode()[0]
df["Gender"].fillna(x,inplace=True)
df
# Out:
#      Age        Income Gender Education Employment_Status  \
# 0   25.0  50000.000000      M  Bachelor        Unemployed
# 1   30.0  60000.000000      F    Master          Employed
# 2   51.0  75000.000000      M    Master        Unemployed
# 3   35.0  63866.666667      F  Bachelor        Unemployed
# 4   40.0  80000.000000      M  Bachelor        Unemployed
# 5   51.0  42000.000000      M    Master          Employed
# 6   22.0  55000.000000      M       PhD               NaN
# 7   28.0  63866.666667      F  Bachelor          Employed
# 8   45.0  67000.000000      M  Bachelor        Unemployed
# 9   50.0  72000.000000      M       PhD          Employed
# 10  51.0  63866.666667      M  Bachelor        Unemployed
# 11  37.0  69000.000000      M    Master        Unemployed
# 12  29.0  59000.000000      F       PhD          Employed
# 13  41.0  68000.000000      M  Bachelor        Unemployed
# 14  48.0  62000.000000      F    Master          Employed
# 15  33.0  71000.000000      F  Bachelor        Unemployed
# 16  38.0  58000.000000      M    Master        Unemployed
# 17  51.0  63866.666667      M       PhD          Employed
# 18  44.0  70000.000000      F  Bachelor        Unemployed
# 19  51.0  63866.666667      M       PhD          Employed
#
#     Years_of_Experience Marital_Status  Children_Count Home_Ownership  \
# 0                   3.0         Single             0.0           Rent
# 1                   5.0        Married             1.0            Own
# 2                   0.0         Single             0.0           Rent
# 3                   8.0        Married             2.0            Own
# 4                  10.0         Single             0.0           Rent
# 5                   2.0        Married             2.0            Own
# 6                   0.0            NaN             NaN            NaN
# 7                   4.0        Married             3.0            Own
# 8                  12.0         Single             1.0           Rent
# 9                  15.0        Married             2.0            Own
# 10                  NaN         Single             2.0           Rent
# 11                  9.0        Married             1.0            Own
# 12                  4.0         Single             0.0           Rent
# 13                 11.0        Married             3.0            Own
# 14                 14.0         Single             2.0           Rent
# 15                  7.0        Married             1.0            Own
# 16                 13.0         Single             2.0           Rent
# 17                  1.0            NaN             0.0           Rent
# 18                  5.0        Married             2.0            Own
# 19                 16.0        Married             NaN            NaN
#
#     Age_Missing  Income_Missing  Gender_Missing
# 0             0               0               0
# 1             0               0               0
# 2             1               0               1
# 3             0               1               0
# 4             0               0               0
# 5             1               0               1
# 6             0               0               0
# 7             0               1               0
# 8             0               0               0
# 9             0               0               0
# 10            1               1               1
# 11            0               0               0
# 12            0               0               0
# 13            0               0               0
# 14            0               0               0
# 15            0               0               0
# 16            0               0               0
# 17            1               1               0
# 18            0               0               0
# 19            0               1               0

# %%
x = df["Age"].mean()
df["Age"].fillna(x,inplace=True)
df
# Out:
#      Age        Income Gender Education Employment_Status  \
# 0   25.0  50000.000000      M  Bachelor        Unemployed
# 1   30.0  60000.000000      F    Master          Employed
# 2   51.0  75000.000000      M    Master        Unemployed
# 3   35.0  63866.666667      F  Bachelor        Unemployed
# 4   40.0  80000.000000      M  Bachelor        Unemployed
# 5   51.0  42000.000000      M    Master          Employed
# 6   22.0  55000.000000      M       PhD               NaN
# 7   28.0  63866.666667      F  Bachelor          Employed
# 8   45.0  67000.000000      M  Bachelor        Unemployed
# 9   50.0  72000.000000      M       PhD          Employed
# 10  51.0  63866.666667      M  Bachelor        Unemployed
# 11  37.0  69000.000000      M    Master        Unemployed
# 12  29.0  59000.000000      F       PhD          Employed
# 13  41.0  68000.000000      M  Bachelor        Unemployed
# 14  48.0  62000.000000      F    Master          Employed
# 15  33.0  71000.000000      F  Bachelor        Unemployed
# 16  38.0  58000.000000      M    Master        Unemployed
# 17  51.0  63866.666667      M       PhD          Employed
# 18  44.0  70000.000000      F  Bachelor        Unemployed
# 19  51.0  63866.666667      M       PhD          Employed
#
#     Years_of_Experience Marital_Status  Children_Count Home_Ownership  \
# 0                   3.0         Single             0.0           Rent
# 1                   5.0        Married             1.0            Own
# 2                   0.0         Single             0.0           Rent
# 3                   8.0        Married             2.0            Own
# 4                  10.0         Single             0.0           Rent
# 5                   2.0        Married             2.0            Own
# 6                   0.0            NaN             NaN            NaN
# 7                   4.0        Married             3.0            Own
# 8                  12.0         Single             1.0           Rent
# 9                  15.0        Married             2.0            Own
# 10                  NaN         Single             2.0           Rent
# 11                  9.0        Married             1.0            Own
# 12                  4.0         Single             0.0           Rent
# 13                 11.0        Married             3.0            Own
# 14                 14.0         Single             2.0           Rent
# 15                  7.0        Married             1.0            Own
# 16                 13.0         Single             2.0           Rent
# 17                  1.0            NaN             0.0           Rent
# 18                  5.0        Married             2.0            Own
# 19                 16.0        Married             NaN            NaN
#
#     Age_Missing  Income_Missing  Gender_Missing
# 0             0               0               0
# 1             0               0               0
# 2             1               0               1
# 3             0               1               0
# 4             0               0               0
# 5             1               0               1
# 6             0               0               0
# 7             0               1               0
# 8             0               0               0
# 9             0               0               0
# 10            1               1               1
# 11            0               0               0
# 12            0               0               0
# 13            0               0               0
# 14            0               0               0
# 15            0               0               0
# 16            0               0               0
# 17            1               1               0
# 18            0               0               0
# 19            0               1               0

# %% [markdown]
# ### Frequent categories imputation

# %%
x = df["Education"].mode()[0]

df["Education"].fillna(x, inplace = True)
df
# Out:
#      Age        Income Gender Education Employment_Status  \
# 0   25.0  50000.000000      M  Bachelor        Unemployed
# 1   30.0  60000.000000      F    Master          Employed
# 2   51.0  75000.000000      M    Master        Unemployed
# 3   35.0  63866.666667      F  Bachelor        Unemployed
# 4   40.0  80000.000000      M  Bachelor        Unemployed
# 5   51.0  42000.000000      M    Master          Employed
# 6   22.0  55000.000000      M       PhD               NaN
# 7   28.0  63866.666667      F  Bachelor          Employed
# 8   45.0  67000.000000      M  Bachelor        Unemployed
# 9   50.0  72000.000000      M       PhD          Employed
# 10  51.0  63866.666667      M  Bachelor        Unemployed
# 11  37.0  69000.000000      M    Master        Unemployed
# 12  29.0  59000.000000      F       PhD          Employed
# 13  41.0  68000.000000      M  Bachelor        Unemployed
# 14  48.0  62000.000000      F    Master          Employed
# 15  33.0  71000.000000      F  Bachelor        Unemployed
# 16  38.0  58000.000000      M    Master        Unemployed
# 17  51.0  63866.666667      M       PhD          Employed
# 18  44.0  70000.000000      F  Bachelor        Unemployed
# 19  51.0  63866.666667      M       PhD          Employed
#
#     Years_of_Experience Marital_Status  Children_Count Home_Ownership  \
# 0                   3.0         Single             0.0           Rent
# 1                   5.0        Married             1.0            Own
# 2                   0.0         Single             0.0           Rent
# 3                   8.0        Married             2.0            Own
# 4                  10.0         Single             0.0           Rent
# 5                   2.0        Married             2.0            Own
# 6                   0.0            NaN             NaN            NaN
# 7                   4.0        Married             3.0            Own
# 8                  12.0         Single             1.0           Rent
# 9                  15.0        Married             2.0            Own
# 10                  NaN         Single             2.0           Rent
# 11                  9.0        Married             1.0            Own
# 12                  4.0         Single             0.0           Rent
# 13                 11.0        Married             3.0            Own
# 14                 14.0         Single             2.0           Rent
# 15                  7.0        Married             1.0            Own
# 16                 13.0         Single             2.0           Rent
# 17                  1.0            NaN             0.0           Rent
# 18                  5.0        Married             2.0            Own
# 19                 16.0        Married             NaN            NaN
#
#     Age_Missing  Income_Missing  Gender_Missing
# 0             0               0               0
# 1             0               0               0
# 2             1               0               1
# 3             0               1               0
# 4             0               0               0
# 5             1               0               1
# 6             0               0               0
# 7             0               1               0
# 8             0               0               0
# 9             0               0               0
# 10            1               1               1
# 11            0               0               0
# 12            0               0               0
# 13            0               0               0
# 14            0               0               0
# 15            0               0               0
# 16            0               0               0
# 17            1               1               0
# 18            0               0               0
# 19            0               1               0

# %%
x = df["Employment_Status"].mode()[0]

df["Employment_Status"].fillna(x, inplace = True)
df
# Out:
#      Age        Income Gender Education Employment_Status  \
# 0   25.0  50000.000000      M  Bachelor        Unemployed
# 1   30.0  60000.000000      F    Master          Employed
# 2   51.0  75000.000000      M    Master        Unemployed
# 3   35.0  63866.666667      F  Bachelor        Unemployed
# 4   40.0  80000.000000      M  Bachelor        Unemployed
# 5   51.0  42000.000000      M    Master          Employed
# 6   22.0  55000.000000      M       PhD        Unemployed
# 7   28.0  63866.666667      F  Bachelor          Employed
# 8   45.0  67000.000000      M  Bachelor        Unemployed
# 9   50.0  72000.000000      M       PhD          Employed
# 10  51.0  63866.666667      M  Bachelor        Unemployed
# 11  37.0  69000.000000      M    Master        Unemployed
# 12  29.0  59000.000000      F       PhD          Employed
# 13  41.0  68000.000000      M  Bachelor        Unemployed
# 14  48.0  62000.000000      F    Master          Employed
# 15  33.0  71000.000000      F  Bachelor        Unemployed
# 16  38.0  58000.000000      M    Master        Unemployed
# 17  51.0  63866.666667      M       PhD          Employed
# 18  44.0  70000.000000      F  Bachelor        Unemployed
# 19  51.0  63866.666667      M       PhD          Employed
#
#     Years_of_Experience Marital_Status  Children_Count Home_Ownership  \
# 0                   3.0         Single             0.0           Rent
# 1                   5.0        Married             1.0            Own
# 2                   0.0         Single             0.0           Rent
# 3                   8.0        Married             2.0            Own
# 4                  10.0         Single             0.0           Rent
# 5                   2.0        Married             2.0            Own
# 6                   0.0            NaN             NaN            NaN
# 7                   4.0        Married             3.0            Own
# 8                  12.0         Single             1.0           Rent
# 9                  15.0        Married             2.0            Own
# 10                  NaN         Single             2.0           Rent
# 11                  9.0        Married             1.0            Own
# 12                  4.0         Single             0.0           Rent
# 13                 11.0        Married             3.0            Own
# 14                 14.0         Single             2.0           Rent
# 15                  7.0        Married             1.0            Own
# 16                 13.0         Single             2.0           Rent
# 17                  1.0            NaN             0.0           Rent
# 18                  5.0        Married             2.0            Own
# 19                 16.0        Married             NaN            NaN
#
#     Age_Missing  Income_Missing  Gender_Missing
# 0             0               0               0
# 1             0               0               0
# 2             1               0               1
# 3             0               1               0
# 4             0               0               0
# 5             1               0               1
# 6             0               0               0
# 7             0               1               0
# 8             0               0               0
# 9             0               0               0
# 10            1               1               1
# 11            0               0               0
# 12            0               0               0
# 13            0               0               0
# 14            0               0               0
# 15            0               0               0
# 16            0               0               0
# 17            1               1               0
# 18            0               0               0
# 19            0               1               0

# %%
x = df["Years_of_Experience"].mean()
df["Years_of_Experience"].fillna(x,inplace=True)
df
# Out:
#      Age        Income Gender Education Employment_Status  \
# 0   25.0  50000.000000      M  Bachelor        Unemployed
# 1   30.0  60000.000000      F    Master          Employed
# 2   51.0  75000.000000      M    Master        Unemployed
# 3   35.0  63866.666667      F  Bachelor        Unemployed
# 4   40.0  80000.000000      M  Bachelor        Unemployed
# 5   51.0  42000.000000      M    Master          Employed
# 6   22.0  55000.000000      M       PhD        Unemployed
# 7   28.0  63866.666667      F  Bachelor          Employed
# 8   45.0  67000.000000      M  Bachelor        Unemployed
# 9   50.0  72000.000000      M       PhD          Employed
# 10  51.0  63866.666667      M  Bachelor        Unemployed
# 11  37.0  69000.000000      M    Master        Unemployed
# 12  29.0  59000.000000      F       PhD          Employed
# 13  41.0  68000.000000      M  Bachelor        Unemployed
# 14  48.0  62000.000000      F    Master          Employed
# 15  33.0  71000.000000      F  Bachelor        Unemployed
# 16  38.0  58000.000000      M    Master        Unemployed
# 17  51.0  63866.666667      M       PhD          Employed
# 18  44.0  70000.000000      F  Bachelor        Unemployed
# 19  51.0  63866.666667      M       PhD          Employed
#
#     Years_of_Experience Marital_Status  Children_Count Home_Ownership  \
# 0              3.000000         Single             0.0           Rent
# 1              5.000000        Married             1.0            Own
# 2              0.000000         Single             0.0           Rent
# 3              8.000000        Married             2.0            Own
# 4             10.000000         Single             0.0           Rent
# 5              2.000000        Married             2.0            Own
# 6              0.000000            NaN             NaN            NaN
# 7              4.000000        Married             3.0            Own
# 8             12.000000         Single             1.0           Rent
# 9             15.000000        Married             2.0            Own
# 10             7.315789         Single             2.0           Rent
# 11             9.000000        Married             1.0            Own
# 12             4.000000         Single             0.0           Rent
# 13            11.000000        Married             3.0            Own
# 14            14.000000         Single             2.0           Rent
# 15             7.000000        Married             1.0            Own
# 16            13.000000         Single             2.0           Rent
# 17             1.000000            NaN             0.0           Rent
# 18             5.000000        Married             2.0            Own
# 19            16.000000        Married             NaN            NaN
#
#     Age_Missing  Income_Missing  Gender_Missing
# 0             0               0               0
# 1             0               0               0
# 2             1               0               1
# 3             0               1               0
# 4             0               0               0
# 5             1               0               1
# 6             0               0               0
# 7             0               1               0
# 8             0               0               0
# 9             0               0               0
# 10            1               1               1
# 11            0               0               0
# 12            0               0               0
# 13            0               0               0
# 14            0               0               0
# 15            0               0               0
# 16            0               0               0
# 17            1               1               0
# 18            0               0               0
# 19            0               1               0

# %%
x = df["Marital_Status"].mode()[0]

df["Marital_Status"].fillna(x, inplace = True)
df
# Out:
#      Age        Income Gender Education Employment_Status  \
# 0   25.0  50000.000000      M  Bachelor        Unemployed
# 1   30.0  60000.000000      F    Master          Employed
# 2   51.0  75000.000000      M    Master        Unemployed
# 3   35.0  63866.666667      F  Bachelor        Unemployed
# 4   40.0  80000.000000      M  Bachelor        Unemployed
# 5   51.0  42000.000000      M    Master          Employed
# 6   22.0  55000.000000      M       PhD        Unemployed
# 7   28.0  63866.666667      F  Bachelor          Employed
# 8   45.0  67000.000000      M  Bachelor        Unemployed
# 9   50.0  72000.000000      M       PhD          Employed
# 10  51.0  63866.666667      M  Bachelor        Unemployed
# 11  37.0  69000.000000      M    Master        Unemployed
# 12  29.0  59000.000000      F       PhD          Employed
# 13  41.0  68000.000000      M  Bachelor        Unemployed
# 14  48.0  62000.000000      F    Master          Employed
# 15  33.0  71000.000000      F  Bachelor        Unemployed
# 16  38.0  58000.000000      M    Master        Unemployed
# 17  51.0  63866.666667      M       PhD          Employed
# 18  44.0  70000.000000      F  Bachelor        Unemployed
# 19  51.0  63866.666667      M       PhD          Employed
#
#     Years_of_Experience Marital_Status  Children_Count Home_Ownership  \
# 0              3.000000         Single             0.0           Rent
# 1              5.000000        Married             1.0            Own
# 2              0.000000         Single             0.0           Rent
# 3              8.000000        Married             2.0            Own
# 4             10.000000         Single             0.0           Rent
# 5              2.000000        Married             2.0            Own
# 6              0.000000        Married             NaN            NaN
# 7              4.000000        Married             3.0            Own
# 8             12.000000         Single             1.0           Rent
# 9             15.000000        Married             2.0            Own
# 10             7.315789         Single             2.0           Rent
# 11             9.000000        Married             1.0            Own
# 12             4.000000         Single             0.0           Rent
# 13            11.000000        Married             3.0            Own
# 14            14.000000         Single             2.0           Rent
# 15             7.000000        Married             1.0            Own
# 16            13.000000         Single             2.0           Rent
# 17             1.000000        Married             0.0           Rent
# 18             5.000000        Married             2.0            Own
# 19            16.000000        Married             NaN            NaN
#
#     Age_Missing  Income_Missing  Gender_Missing
# 0             0               0               0
# 1             0               0               0
# 2             1               0               1
# 3             0               1               0
# 4             0               0               0
# 5             1               0               1
# 6             0               0               0
# 7             0               1               0
# 8             0               0               0
# 9             0               0               0
# 10            1               1               1
# 11            0               0               0
# 12            0               0               0
# 13            0               0               0
# 14            0               0               0
# 15            0               0               0
# 16            0               0               0
# 17            1               1               0
# 18            0               0               0
# 19            0               1               0

# %%
x = df["Children_Count"].mean()
df["Children_Count"].fillna(x,inplace=True)
df
# Out:
#      Age        Income Gender Education Employment_Status  \
# 0   25.0  50000.000000      M  Bachelor        Unemployed
# 1   30.0  60000.000000      F    Master          Employed
# 2   51.0  75000.000000      M    Master        Unemployed
# 3   35.0  63866.666667      F  Bachelor        Unemployed
# 4   40.0  80000.000000      M  Bachelor        Unemployed
# 5   51.0  42000.000000      M    Master          Employed
# 6   22.0  55000.000000      M       PhD        Unemployed
# 7   28.0  63866.666667      F  Bachelor          Employed
# 8   45.0  67000.000000      M  Bachelor        Unemployed
# 9   50.0  72000.000000      M       PhD          Employed
# 10  51.0  63866.666667      M  Bachelor        Unemployed
# 11  37.0  69000.000000      M    Master        Unemployed
# 12  29.0  59000.000000      F       PhD          Employed
# 13  41.0  68000.000000      M  Bachelor        Unemployed
# 14  48.0  62000.000000      F    Master          Employed
# 15  33.0  71000.000000      F  Bachelor        Unemployed
# 16  38.0  58000.000000      M    Master        Unemployed
# 17  51.0  63866.666667      M       PhD          Employed
# 18  44.0  70000.000000      F  Bachelor        Unemployed
# 19  51.0  63866.666667      M       PhD          Employed
#
#     Years_of_Experience Marital_Status  Children_Count Home_Ownership  \
# 0              3.000000         Single        0.000000           Rent
# 1              5.000000        Married        1.000000            Own
# 2              0.000000         Single        0.000000           Rent
# 3              8.000000        Married        2.000000            Own
# 4             10.000000         Single        0.000000           Rent
# 5              2.000000        Married        2.000000            Own
# 6              0.000000        Married        1.333333            NaN
# 7              4.000000        Married        3.000000            Own
# 8             12.000000         Single        1.000000           Rent
# 9             15.000000        Married        2.000000            Own
# 10             7.315789         Single        2.000000           Rent
# 11             9.000000        Married        1.000000            Own
# 12             4.000000         Single        0.000000           Rent
# 13            11.000000        Married        3.000000            Own
# 14            14.000000         Single        2.000000           Rent
# 15             7.000000        Married        1.000000            Own
# 16            13.000000         Single        2.000000           Rent
# 17             1.000000        Married        0.000000           Rent
# 18             5.000000        Married        2.000000            Own
# 19            16.000000        Married        1.333333            NaN
#
#     Age_Missing  Income_Missing  Gender_Missing
# 0             0               0               0
# 1             0               0               0
# 2             1               0               1
# 3             0               1               0
# 4             0               0               0
# 5             1               0               1
# 6             0               0               0
# 7             0               1               0
# 8             0               0               0
# 9             0               0               0
# 10            1               1               1
# 11            0               0               0
# 12            0               0               0
# 13            0               0               0
# 14            0               0               0
# 15            0               0               0
# 16            0               0               0
# 17            1               1               0
# 18            0               0               0
# 19            0               1               0

# %%
x = df["Home_Ownership"].mode()[0]

df["Home_Ownership"].fillna(x, inplace = True)
df
# Out:
#      Age        Income Gender Education Employment_Status  \
# 0   25.0  50000.000000      M  Bachelor        Unemployed
# 1   30.0  60000.000000      F    Master          Employed
# 2   51.0  75000.000000      M    Master        Unemployed
# 3   35.0  63866.666667      F  Bachelor        Unemployed
# 4   40.0  80000.000000      M  Bachelor        Unemployed
# 5   51.0  42000.000000      M    Master          Employed
# 6   22.0  55000.000000      M       PhD        Unemployed
# 7   28.0  63866.666667      F  Bachelor          Employed
# 8   45.0  67000.000000      M  Bachelor        Unemployed
# 9   50.0  72000.000000      M       PhD          Employed
# 10  51.0  63866.666667      M  Bachelor        Unemployed
# 11  37.0  69000.000000      M    Master        Unemployed
# 12  29.0  59000.000000      F       PhD          Employed
# 13  41.0  68000.000000      M  Bachelor        Unemployed
# 14  48.0  62000.000000      F    Master          Employed
# 15  33.0  71000.000000      F  Bachelor        Unemployed
# 16  38.0  58000.000000      M    Master        Unemployed
# 17  51.0  63866.666667      M       PhD          Employed
# 18  44.0  70000.000000      F  Bachelor        Unemployed
# 19  51.0  63866.666667      M       PhD          Employed
#
#     Years_of_Experience Marital_Status  Children_Count Home_Ownership  \
# 0              3.000000         Single        0.000000           Rent
# 1              5.000000        Married        1.000000            Own
# 2              0.000000         Single        0.000000           Rent
# 3              8.000000        Married        2.000000            Own
# 4             10.000000         Single        0.000000           Rent
# 5              2.000000        Married        2.000000            Own
# 6              0.000000        Married        1.333333            Own
# 7              4.000000        Married        3.000000            Own
# 8             12.000000         Single        1.000000           Rent
# 9             15.000000        Married        2.000000            Own
# 10             7.315789         Single        2.000000           Rent
# 11             9.000000        Married        1.000000            Own
# 12             4.000000         Single        0.000000           Rent
# 13            11.000000        Married        3.000000            Own
# 14            14.000000         Single        2.000000           Rent
# 15             7.000000        Married        1.000000            Own
# 16            13.000000         Single        2.000000           Rent
# 17             1.000000        Married        0.000000           Rent
# 18             5.000000        Married        2.000000            Own
# 19            16.000000        Married        1.333333            Own
#
#     Age_Missing  Income_Missing  Gender_Missing
# 0             0               0               0
# 1             0               0               0
# 2             1               0               1
# 3             0               1               0
# 4             0               0               0
# 5             1               0               1
# 6             0               0               0
# 7             0               1               0
# 8             0               0               0
# 9             0               0               0
# 10            1               1               1
# 11            0               0               0
# 12            0               0               0
# 13            0               0               0
# 14            0               0               0
# 15            0               0               0
# 16            0               0               0
# 17            1               1               0
# 18            0               0               0
# 19            0               1               0

# %%
columns_to_convert = ['Age', 'Income','Years_of_Experience','Children_Count']
df[columns_to_convert] = df[columns_to_convert].astype(int)
df
# Out:
#     Age  Income Gender Education Employment_Status  Years_of_Experience  \
# 0    25   50000      M  Bachelor        Unemployed                    3
# 1    30   60000      F    Master          Employed                    5
# 2    51   75000      M    Master        Unemployed                    0
# 3    35   63866      F  Bachelor        Unemployed                    8
# 4    40   80000      M  Bachelor        Unemployed                   10
# 5    51   42000      M    Master          Employed                    2
# 6    22   55000      M       PhD        Unemployed                    0
# 7    28   63866      F  Bachelor          Employed                    4
# 8    45   67000      M  Bachelor        Unemployed                   12
# 9    50   72000      M       PhD          Employed                   15
# 10   51   63866      M  Bachelor        Unemployed                    7
# 11   37   69000      M    Master        Unemployed                    9
# 12   29   59000      F       PhD          Employed                    4
# 13   41   68000      M  Bachelor        Unemployed                   11
# 14   48   62000      F    Master          Employed                   14
# 15   33   71000      F  Bachelor        Unemployed                    7
# 16   38   58000      M    Master        Unemployed                   13
# 17   51   63866      M       PhD          Employed                    1
# 18   44   70000      F  Bachelor        Unemployed                    5
# 19   51   63866      M       PhD          Employed                   16
#
#    Marital_Status  Children_Count Home_Ownership  Age_Missing  Income_Missing  \
# 0          Single               0           Rent            0               0
# 1         Married               1            Own            0               0
# 2          Single               0           Rent            1               0
# 3         Married               2            Own            0               1
# 4          Single               0           Rent            0               0
# 5         Married               2            Own            1               0
# 6         Married               1            Own            0               0
# 7         Married               3            Own            0               1
# 8          Single               1           Rent            0               0
# 9         Married               2            Own            0               0
# 10         Single               2           Rent            1               1
# 11        Married               1            Own            0               0
# 12         Single               0           Rent            0               0
# 13        Married               3            Own            0               0
# 14         Single               2           Rent            0               0
# 15        Married               1            Own            0               0
# 16         Single               2           Rent            0               0
# 17        Married               0           Rent            1               1
# 18        Married               2            Own            0               0
# 19        Married               1            Own            0               1
#
#     Gender_Missing
# 0                0
# 1                0
# 2                1
# 3                0
# 4                0
# 5                1
# 6                0
# 7                0
# 8                0
# 9                0
# 10               1
# 11               0
# 12               0
# 13               0
# 14               0
# 15               0
# 16               0
# 17               0
# 18               0
# 19               0

# %%
data = {
    'Age': [25, 30, 22, np.nan, np.nan, np.nan, 28, 32, 29],
}

df = pd.DataFrame(data)

# Calculate the extreme value (e.g., 99th percentile) for Age
extreme_value = df['Age'].quantile(0.99)

# Replace missing values with the extreme value
df['Age'].fillna(extreme_value, inplace=True)

# Print the updated DataFrame
print(df)
# Out:
#     Age
# 0  25.0
# 1  30.0
# 2  22.0
# 3  31.9
# 4  31.9
# 5  31.9
# 6  28.0
# 7  32.0
# 8  29.0

# %%
df
# Out:
#     Age
# 0  25.0
# 1  30.0
# 2  22.0
# 3  31.9
# 4  31.9
# 5  31.9
# 6  28.0
# 7  32.0
# 8  29.0
